# %% [markdown]
# # Supervised ResNet

# %% [markdown]
# ### Import libraries and set constants

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import datasets
import torchvision.transforms as tt
from torchvision.utils import make_grid
from torch.utils.data import DataLoader

# %matplotlib inline

# %%
INPUT_SIZE = 96
BATCH_SIZE = 32

# %% [markdown]
# ### Data  augmentation and normalization

# %%
stats = ((0.485, 0.456, 0.406), (0.229, 0.224, 0.225))
train_transforms = tt.Compose([tt.RandomCrop(INPUT_SIZE, padding=4, padding_mode='reflect'), 
                         tt.RandomHorizontalFlip(), 
                          tt.RandomRotation(10), 
                          tt.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.1, hue=0.1),
                         tt.ToTensor(), 
                         tt.Normalize(*stats,inplace=True)])
test_transforms = tt.Compose([tt.ToTensor(), tt.Normalize(*stats)])

# %% [markdown]
# ###Loading and formatting datasets

# %%
ds_train = datasets.STL10(
    root="data",
    split='train',
    download=True,
    transform=train_transforms
)
# Out:
# Downloading http://ai.stanford.edu/~acoates/stl10/stl10_binary.tar.gz to data/stl10_binary.tar.gz
# HBox(children=(FloatProgress(value=0.0, max=2640397119.0), HTML(value='')))
# Extracting data/stl10_binary.tar.gz to data

# %%
ds_test = datasets.STL10(
    root="data",
    split='test',
    download=True,
    transform=test_transforms
)
# Out:
# Files already downloaded and verified

# %%
# Creating dataloaders
dl_train = DataLoader(ds_train, batch_size=BATCH_SIZE, shuffle=True, num_workers=2, pin_memory=True)
dl_test = DataLoader(ds_test, batch_size=BATCH_SIZE, shuffle=True, num_workers=2, pin_memory=True)

# %%
# Display sample
def denormalize(images, means, stds):
    means = torch.tensor(means).reshape(1, 3, 1, 1)
    stds = torch.tensor(stds).reshape(1, 3, 1, 1)
    return images * stds + means

def show_batch(dl):
    for images, labels in dl:
        fig, ax = plt.subplots(figsize=(9, 9))
        ax.set_xticks([]); ax.set_yticks([])
        denorm_images = denormalize(images, *stats)
        ax.imshow(make_grid(denorm_images[:32], nrow=8).permute(1, 2, 0).clamp(0,1))
        break

# %%
show_batch(dl_train)

# %% [markdown]
# ### Set up GPU

# %%
def get_default_device():
    """Pick GPU if available, else CPU"""
    if torch.cuda.is_available():
        return torch.device('cuda')
    else:
        return torch.device('cpu')
    
def to_device(data, device):
    """Move tensor(s) to chosen device"""
    if isinstance(data, (list,tuple)):
        return [to_device(x, device) for x in data]
    return data.to(device, non_blocking=True)

class DeviceDataLoader():
    """Wrap a dataloader to move data to a device"""
    def __init__(self, dl, device):
        self.dl = dl
        self.device = device
        
    def __iter__(self):
        """Yield a batch of data after moving it to device"""
        for b in self.dl: 
            yield to_device(b, self.device)

    def __len__(self):
        """Number of batches"""
        return len(self.dl)

# %%
device = get_default_device()
device
# Out:
# device(type='cuda')

# %%
# Shifting data
dl_train = DeviceDataLoader(dl_train, device)
dl_test = DeviceDataLoader(dl_test, device)

# %%
torch.backends.cudnn.benchmark = True

# %% [markdown]
# ### Framing the ResNet Model

# %%
# Convolution block
def conv(in_channels, out_channels, kernal_size=3, stride=1, padding=0):
    layer = nn.Sequential(nn.Conv2d(in_channels, out_channels, kernal_size, stride, padding, bias=False), 
                          nn.BatchNorm2d(out_channels),# Batch normalization removes need for bias
                          nn.ReLU())
    return layer

# %%
#Accuracy Function
def accuracy(outputs, labels):
    _, preds = torch.max(outputs, dim=1)
    return torch.tensor(torch.sum(preds == labels).item() / len(preds))

# %%
# ResNet model
class ResNet(nn.Module):

    def __init__(self, channels=3, classes=10):
        super(ResNet, self).__init__()

        self.is_compiled = False

        # Conv #1
        self.conv_1 = conv(channels, 50) # 50x94x94
        self.pool_1 = nn.MaxPool2d(2) # 50x47x47

        # Res #1
        self.res_1 = nn.Sequential(conv(50, 50, padding=1), conv(50, 50, padding=1)) # 50x47x47
        
        # Conv #2
        self.conv_2 = conv(50, 100) # 100x45x45
        self.pool_2 = nn.MaxPool2d(2) # 100x22x22

        # Flatten
        self.flatten = nn.Flatten() # 100*22*22

        # Dropout #1
        self.dropout_1 = nn.Dropout(0.3)

        # Dense #1
        self.dense_1 = nn.Linear(100*22*22, 512)
        
        # Dropout #2
        self.dropout_2 = nn.Dropout(0.3)
        
        # Dense #2
        self.dense_2 = nn.Linear(512, 32) 
        
        # Dropout #3
        self.dropout_3 = nn.Dropout(0.3)

        # Output
        self.out = nn.Linear(32, classes)
    
    def forward(self, input):
        out = self.conv_1(input)
        out = self.pool_1(out)
        out = self.res_1(out) + out
        out = self.conv_2(out)
        out = self.pool_2(out)
        out = self.flatten(out)
        out = self.dropout_1(out)
        out = self.dense_1(out)
        out = self.dropout_2(out)
        out = self.dense_2(out)
        out = self.dropout_3(out)
        out = self.out(out)
        return out
    
    def training_step(self, batch):
        images, labels = batch
        out = self(images)
        loss = self.loss_func(out, labels)
        return loss
    
    def validation_step(self, batch):
        images, labels = batch
        out = self(images)
        loss = self.loss_func(out, labels)
        acc = self.accuracy(out, labels)
        return {'val_loss': loss.detach(), 'val_acc': acc}
    
    @torch.no_grad()
    def evaluate(self, val_loader):
        self.eval()
        outputs = [self.validation_step(batch) for batch in val_loader]
        batch_losses = [x['val_loss'] for x in outputs]
        epoch_loss = torch.stack(batch_losses).mean()
        batch_accs = [x['val_acc'] for x in outputs]
        epoch_acc = torch.stack(batch_accs).mean()
        return {'val_loss': epoch_loss.item(), 'val_acc': epoch_acc.item()}
    
    def compile(self, loss_func=F.cross_entropy, accuracy=accuracy, opt_func=torch.optim.Adam):
        self.is_compiled = True
        self.loss_func = loss_func
        self.accuracy = accuracy
        self.opt_func = opt_func

    def fit(self, train_loader, test_loader, epochs, start_epoch=1, lr = 0.0004):
        if(not self.is_compiled):
            self.compile()
        history = []
        optimizer = self.opt_func(self.parameters(), lr)
        for epoch in range(start_epoch, start_epoch+epochs):
            # Training Phase 
            self.train()
            train_losses = []
            for batch in train_loader:
                loss = self.training_step(batch)
                train_losses.append(loss)
                loss.backward()
                optimizer.step()
                optimizer.zero_grad(set_to_none = True)
   

            # Validation phase
            result = self.evaluate(test_loader)
            result['train_loss'] = torch.stack(train_losses).mean().item()

            print("Epoch [{}/{}], train_loss: {:.4f}, val_loss: {:.4f}, val_acc: {:.4f}"
                                              .format(epoch, (start_epoch+epochs-1), result['train_loss'], result['val_loss'], result['val_acc']))

            history.append(result)
        return history

# %% [markdown]
# ### Training the model

# %%
model = ResNet()
model = to_device(model, device)
model
# Out:
# ResNet(
#   (conv_1): Sequential(
#     (0): Conv2d(3, 50, kernel_size=(3, 3), stride=(1, 1), bias=False)
#     (1): BatchNorm2d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#   )
#   (pool_1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (res_1): Sequential(
#     (0): Sequential(
#       (0): Conv2d(50, 50, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (1): Sequential(
#       (0): Conv2d(50, 50, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#   )
#   (conv_2): Sequential(
#     (0): Conv2d(50, 100, kernel_size=(3, 3), stride=(1, 1), bias=False)
#     (1): BatchNorm2d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#   )
#   (pool_2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (dropout_1): Dropout(p=0.3, inplace=False)
#   (dense_1): Linear(in_features=48400, out_features=512, bias=True)
#   (dropout_2): Dropout(p=0.3, inplace=False)
#   (dense_2): Linear(in_features=512, out_features=32, bias=True)
#   (dropout_3): Dropout(p=0.3, inplace=False)
#   (out): Linear(in_features=32, out_features=10, bias=True)
# )

# %%
model.compile()

# %%
history = model.fit(dl_train, dl_test,90)
# Out:
# Epoch [1/90], train_loss: 5.4536, val_loss: 2.0195, val_acc: 0.3632
# Epoch [2/90], train_loss: 2.4593, val_loss: 2.4103, val_acc: 0.3124
# Epoch [3/90], train_loss: 2.2603, val_loss: 1.8105, val_acc: 0.3578
# Epoch [4/90], train_loss: 1.9861, val_loss: 1.5507, val_acc: 0.4441
# Epoch [5/90], train_loss: 1.8762, val_loss: 1.4623, val_acc: 0.4841
# Epoch [6/90], train_loss: 1.7722, val_loss: 1.4768, val_acc: 0.4865
# Epoch [7/90], train_loss: 1.6407, val_loss: 1.6158, val_acc: 0.4505
# Epoch [8/90], train_loss: 1.7046, val_loss: 1.4002, val_acc: 0.5056
# Epoch [9/90], train_loss: 1.6345, val_loss: 1.3150, val_acc: 0.5316
# Epoch [10/90], train_loss: 1.5764, val_loss: 1.3623, val_acc: 0.5172
# Epoch [11/90], train_loss: 1.4379, val_loss: 1.2739, val_acc: 0.5397
# Epoch [12/90], train_loss: 1.4689, val_loss: 1.4112, val_acc: 0.4965
# Epoch [13/90], train_loss: 1.5347, val_loss: 1.3178, val_acc: 0.5272
# Epoch [14/90], train_loss: 1.4298, val_loss: 1.2118, val_acc: 0.5577
# Epoch [15/90], train_loss: 1.3918, val_loss: 1.2731, val_acc: 0.5496
# Epoch [16/90], train_loss: 1.3778, val_loss: 1.1490, val_acc: 0.5868
# Epoch [17/90], train_loss: 1.3613, val_loss: 1.1632, val_acc: 0.5792
# Epoch [18/90], train_loss: 1.2872, val_loss: 1.1619, val_acc: 0.5836
# Epoch [19/90], train_loss: 1.3188, val_loss: 1.2002, val_acc: 0.5768
# Epoch [20/90], train_loss: 1.3084, val_loss: 1.1493, val_acc: 0.5840
# Epoch [21/90], train_loss: 1.2782, val_loss: 1.1008, val_acc: 0.6043
# Epoch [22/90], train_loss: 1.2183, val_loss: 1.1307, val_acc: 0.6088
# Epoch [23/90], train_loss: 1.1562, val_loss: 1.3094, val_acc: 0.5564
# Epoch [24/90], train_loss: 1.1963, val_loss: 1.0735, val_acc: 0.6158
# Epoch [25/90], train_loss: 1.1154, val_loss: 1.0708, val_acc: 0.6137
# Epoch [26/90], train_loss: 1.1499, val_loss: 1.1638, val_acc: 0.6008
# Epoch [27/90], train_loss: 1.1678, val_loss: 1.0440, val_acc: 0.6337
# Epoch [28/90], train_loss: 1.1136, val_loss: 1.0914, val_acc: 0.6034
# Epoch [29/90], train_loss: 1.1297, val_loss: 1.0800, val_acc: 0.6224
# Epoch [30/90], train_loss: 1.1489, val_loss: 1.1241, val_acc: 0.5995
# Epoch [31/90], train_loss: 1.0880, val_loss: 1.0140, val_acc: 0.6469
# Epoch [32/90], train_loss: 1.0206, val_loss: 1.0322, val_acc: 0.6313
# Epoch [33/90], train_loss: 1.0244, val_loss: 0.9920, val_acc: 0.6477
# Epoch [34/90], train_loss: 1.0711, val_loss: 1.0874, val_acc: 0.6197
# Epoch [35/90], train_loss: 1.0318, val_loss: 1.0290, val_acc: 0.6404
# Epoch [36/90], train_loss: 1.0140, val_loss: 1.0111, val_acc: 0.6404
# Epoch [37/90], train_loss: 1.0061, val_loss: 0.9980, val_acc: 0.6478
# Epoch [38/90], train_loss: 1.0700, val_loss: 1.0029, val_acc: 0.6437
# Epoch [39/90], train_loss: 0.9930, val_loss: 1.0002, val_acc: 0.6551
# Epoch [40/90], train_loss: 0.9662, val_loss: 1.0188, val_acc: 0.6384
# Epoch [41/90], train_loss: 0.9829, val_loss: 0.9852, val_acc: 0.6540
# Epoch [42/90], train_loss: 0.9023, val_loss: 1.0115, val_acc: 0.6463
# Epoch [43/90], train_loss: 0.9698, val_loss: 1.0594, val_acc: 0.6393
# Epoch [44/90], train_loss: 1.1061, val_loss: 0.9704, val_acc: 0.6554
# Epoch [45/90], train_loss: 0.9375, val_loss: 0.9582, val_acc: 0.6607
# Epoch [46/90], train_loss: 0.9206, val_loss: 0.9712, val_acc: 0.6633
# Epoch [47/90], train_loss: 0.8970, val_loss: 0.9428, val_acc: 0.6725
# Epoch [48/90], train_loss: 0.8664, val_loss: 0.9265, val_acc: 0.6775
# Epoch [49/90], train_loss: 0.8698, val_loss: 0.9735, val_acc: 0.6618
# Epoch [50/90], train_loss: 0.9019, val_loss: 0.9226, val_acc: 0.6789
# Epoch [51/90], train_loss: 0.8689, val_loss: 1.0153, val_acc: 0.6601
# Epoch [52/90], train_loss: 0.9983, val_loss: 0.9344, val_acc: 0.6772
# Epoch [53/90], train_loss: 0.8931, val_loss: 0.9087, val_acc: 0.6817
# Epoch [54/90], train_loss: 0.8353, val_loss: 0.9481, val_acc: 0.6725
# Epoch [55/90], train_loss: 0.8309, val_loss: 0.9249, val_acc: 0.6787
# Epoch [56/90], train_loss: 0.8134, val_loss: 0.9464, val_acc: 0.6725
# Epoch [57/90], train_loss: 0.8402, val_loss: 0.9804, val_acc: 0.6729
# Epoch [58/90], train_loss: 0.8217, val_loss: 0.9528, val_acc: 0.6758
# Epoch [59/90], train_loss: 0.7904, val_loss: 0.9244, val_acc: 0.6880
# Epoch [60/90], train_loss: 0.8088, val_loss: 0.8754, val_acc: 0.6987
# Epoch [61/90], train_loss: 0.7633, val_loss: 0.9505, val_acc: 0.6860
# Epoch [62/90], train_loss: 0.7933, val_loss: 1.0280, val_acc: 0.6600
# Epoch [63/90], train_loss: 0.9730, val_loss: 0.9574, val_acc: 0.6726
# Epoch [64/90], train_loss: 0.8159, val_loss: 0.9059, val_acc: 0.6904
# Epoch [65/90], train_loss: 0.7844, val_loss: 0.9767, val_acc: 0.6674
# Epoch [66/90], train_loss: 0.7626, val_loss: 0.9442, val_acc: 0.6874
# Epoch [67/90], train_loss: 0.8077, val_loss: 0.9224, val_acc: 0.6907
# Epoch [68/90], train_loss: 0.8123, val_loss: 0.9926, val_acc: 0.6721
# Epoch [69/90], train_loss: 0.7748, val_loss: 0.9969, val_acc: 0.6695
# Epoch [70/90], train_loss: 0.7676, val_loss: 0.8961, val_acc: 0.6932
# Epoch [71/90], train_loss: 0.7604, val_loss: 1.0276, val_acc: 0.6597
# Epoch [72/90], train_loss: 0.8248, val_loss: 0.9818, val_acc: 0.6776
# Epoch [73/90], train_loss: 0.7163, val_loss: 0.9314, val_acc: 0.6916
# Epoch [74/90], train_loss: 0.7449, val_loss: 0.9053, val_acc: 0.6994
# Epoch [75/90], train_loss: 0.7247, val_loss: 0.8840, val_acc: 0.7045
# Epoch [76/90], train_loss: 0.7231, val_loss: 0.9287, val_acc: 0.6892
# Epoch [77/90], train_loss: 0.7517, val_loss: 0.9381, val_acc: 0.6921
# Epoch [78/90], train_loss: 0.7141, val_loss: 0.9078, val_acc: 0.7008
# Epoch [79/90], train_loss: 0.6791, val_loss: 1.1285, val_acc: 0.6471
# Epoch [80/90], train_loss: 0.7155, val_loss: 0.9628, val_acc: 0.6848
# Epoch [81/90], train_loss: 0.7128, val_loss: 0.9754, val_acc: 0.6886
# Epoch [82/90], train_loss: 0.7829, val_loss: 0.9325, val_acc: 0.7018
# Epoch [83/90], train_loss: 0.8529, val_loss: 0.9332, val_acc: 0.6876
# Epoch [84/90], train_loss: 0.7564, val_loss: 0.9086, val_acc: 0.7005
# Epoch [85/90], train_loss: 0.6607, val_loss: 0.9262, val_acc: 0.6957
# Epoch [86/90], train_loss: 0.6757, val_loss: 0.9008, val_acc: 0.6966
# Epoch [87/90], train_loss: 0.6992, val_loss: 0.8869, val_acc: 0.7085
# Epoch [88/90], train_loss: 0.6721, val_loss: 0.8952, val_acc: 0.7057
# Epoch [89/90], train_loss: 0.6371, val_loss: 0.9034, val_acc: 0.7047
# Epoch [90/90], train_loss: 0.6224, val_loss: 0.9525, val_acc: 0.6884

# %%
torch.save(model.state_dict(), 'ResNetv1')

# %%
def plot(history):
    # Accuracy plot
    accuracies = [x['val_acc'] for x in history]
    plt.plot(accuracies, '-x')
    plt.xlabel('epoch')
    plt.ylabel('accuracy')
    plt.title('Accuracy vs. No. of epochs');
    plt.show()

    # Loss plot
    train_losses = [x.get('train_loss') for x in history]
    val_losses = [x['val_loss'] for x in history]
    plt.plot(train_losses, '-bx')
    plt.plot(val_losses, '-rx')
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.legend(['Training', 'Validation'])
    plt.title('Loss vs. No. of epochs');
    plt.show()

# %%
plot(history)
